# %% [markdown]
# <a href="https://colab.research.google.com/github/dannabarrera292002PROGRAMACION/PROGRAMACION-/blob/main/Copia_de_TRABAJOPRACTICO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #SIMULACION BASICA DE INVERSION
# ##Vamos a modelar un proyecto de inversion

# %% [markdown]
# #DECLARAR LAS VARIABLES FINANCIERAS

# %%
inversion_inicial=50000000 #esta variable es de tipo entero(int)
print(type(inversion_inicial))
("")
tasa_descuento=0.10 #esta variable es de tipo decimal(float)
print(type(tasa_descuento))
("")
# Out:
# <class 'int'>
# <class 'float'>
# ''

# %%
flujo_1=1500000
flujo_2=1800000
flujo_3=1200000

# %%
print(type(flujo_1))
print(type(flujo_2))
print(type(flujo_3))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
total_flujos=flujo_1+flujo_2+flujo_3
print("TOTAL FLUJOS RESIVIDOS",total_flujos)
# Out:
# TOTAL FLUJOS RESIVIDOS 4500000

# %%
print(type(total_flujos))
# Out:
# <class 'int'>

# %% [markdown]
# ##COMPARACIONES

# %%
proyecto_rentable = total_flujos > inversion_inicial

# %%
print("¿el proyecto recupera LA INVERSION?"),proyecto_rentable
# Out:
# ¿el proyecto recupera LA INVERSION?
# (None, False)

# %%
print(type(proyecto_rentable))
# Out:
# <class 'bool'>

# %%
#definicion de variables
nombre_proyecto="inversiones aaa"
rentabilidad_esperada=0.10
numero_inversionistas=5
proyecto_aprobado=True

# %%
print(type(nombre_proyecto))
print(type(rentabilidad_esperada))
print(type(numero_inversionistas))
print(type(proyecto_aprobado))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'bool'>

# %%
nombre_proyecto="inversion mia"#(STRING)
#rentabilidad_esperada:(float)
#numero_inversionistas(int)
#proyecto_aprobado(bool)

# %%
type(nombre_proyecto)
# Out:
# str

# %% [markdown]
# #ACTIVIDAD PRACTICA LISTAS

# %% [markdown]
# ##1.INGRESOS MENSUALES

# %%
ingresos=[320000,280000,350000,400000]
print(ingresos)
# Out:
# [320000, 280000, 350000, 400000]

# %%
# imprimir el primer ingreso
print(ingresos[0])
# Out:
# 320000

# %%
#imprimir ultimo ingreso

print(ingresos[3])
# Out:
# 400000

# %%
ingresos.append(300000)

# %%
#verificar sin un valor existe
300000 in ingresos
# Out:
# True

# %%
320000 in ingresos
# Out:
# True

# %%
ingresos.sort()

# %%
print(ingresos)
# Out:
# [280000, 300000, 320000, 350000, 400000]

# %%
numeros =[6,3,7,1,9]

# %%
print(ingresos)
# Out:
# [280000, 300000, 320000, 350000, 400000]

# %%
#eliminar el valor que se encuentra en la posicion 2
ingresos.pop(2)
# Out:
# 320000

# %%
ingresos.index(300000)
# Out:
# 1

# %%
ingresos.pop(1)
# Out:
# 300000

# %%
print(ingresos)
# Out:
# [280000, 350000, 400000]
