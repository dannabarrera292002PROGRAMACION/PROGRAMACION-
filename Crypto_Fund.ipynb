# %% [markdown]
# <a href="https://colab.research.google.com/github/dannabarrera292002PROGRAMACION/PROGRAMACION-/blob/main/Crypto_Fund.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance pandas plotly streamlit

import yfinance as yf
import pandas as pd
import plotly.express as px
import streamlit as st
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 49.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 76.2 MB/s eta 0:00:00
# ...

# %%
import yfinance as yf

# Descargar datos de cada criptomoneda
btc = yf.download("BTC-USD", start="2026-04-01", end="2026-04-30", interval="1d")
eth = yf.download("ETH-USD", start="2026-04-01", end="2026-04-30", interval="1d")
sol = yf.download("SOL-USD", start="2026-04-01", end="2026-04-30", interval="1d")
ada = yf.download("ADA-USD", start="2026-04-01", end="2026-04-30", interval="1d")
ltc = yf.download("LTC-USD", start="2026-04-01", end="2026-04-30", interval="1d")
# Out:
# /tmp/ipykernel_2278/4141816512.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   btc = yf.download("BTC-USD", start="2026-04-01", end="2026-04-30", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_2278/4141816512.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   eth = yf.download("ETH-USD", start="2026-04-01", end="2026-04-30", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_2278/4141816512.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   sol = yf.download("SOL-USD", start="2026-04-01", end="2026-04-30", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_2278/4141816512.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
# ...

# %%
btc.head()
# Out:
# Price              Close          High           Low          Open  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2026-04-01  68078.554688  69230.359375  67555.359375  68232.890625
# 2026-04-02  66888.570312  68633.148438  65725.257812  68077.898438
# 2026-04-03  66931.101562  67296.234375  66281.539062  66889.015625
# 2026-04-04  67290.515625  67515.015625  66769.640625  66938.648438
# 2026-04-05  68981.898438  69087.656250  66610.632812  67291.195312
#
# Price            Volume retorno
# Ticker          BTC-USD
# Date
# 2026-04-01  36465393617     NaN
# 2026-04-02  39323384518     NaN
# 2026-04-03  22815543346     NaN
# 2026-04-04  15878814963     NaN
# 2026-04-05  22972648674     NaN

# %%
eth.head()

# %%
sol.head()

# %%
ada.head()

# %%
ltc.head()

# %%
# btc['Close'] tiene los precios de cierre
btc['retorno'] = btc['Close'].pct_change()
eth['retorno'] = eth['Close'].pct_change()
sol['retorno'] = sol['Close'].pct_change()
ada['retorno'] = ada['Close'].pct_change()
ltc['retorno'] = ltc['Close'].pct_change()

# %%
# Mostrar solo 'close' y 'retorno' para BTC
btc[['Close', 'retorno']].head()
# Out:
# Price              Close   retorno
# Ticker           BTC-USD
# Date
# 2026-04-01  68078.554688       NaN
# 2026-04-02  66888.570312 -0.017480
# 2026-04-03  66931.101562  0.000636
# 2026-04-04  67290.515625  0.005370
# 2026-04-05  68981.898438  0.025136

# %%
eth[['Close', 'retorno']].head()
# Out:
# Price             Close   retorno
# Ticker          ETH-USD
# Date
# 2026-04-01  2138.737061       NaN
# 2026-04-02  2056.852539 -0.038286
# 2026-04-03  2053.385254 -0.001686
# 2026-04-04  2065.351562  0.005828
# 2026-04-05  2108.995605  0.021132

# %%
sol[['Close', 'retorno']].head()
# Out:
# Price           Close   retorno
# Ticker        SOL-USD
# Date
# 2026-04-01  81.195259       NaN
# 2026-04-02  78.951317 -0.027636
# 2026-04-03  80.368546  0.017951
# 2026-04-04  80.808380  0.005473
# 2026-04-05  81.854492  0.012946

# %%
ada[['Close', 'retorno']].head()
# Out:
# Price          Close   retorno
# Ticker       ADA-USD
# Date
# 2026-04-01  0.248058       NaN
# 2026-04-02  0.239358 -0.035072
# 2026-04-03  0.246168  0.028451
# 2026-04-04  0.247949  0.007235
# 2026-04-05  0.250427  0.009994

# %%
ltc[['Close', 'retorno']].head()
# Out:
# Price           Close   retorno
# Ticker        LTC-USD
# Date
# 2026-04-01  53.805855       NaN
# 2026-04-02  52.260174 -0.028727
# 2026-04-03  53.208050  0.018138
# 2026-04-04  53.574547  0.006888
# 2026-04-05  54.114513  0.010079
